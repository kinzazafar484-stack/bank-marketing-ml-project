# %%
import pandas as pd

# %%
import seaborn as sns

# %%
X_train=pd.read_csv('x_train_encoded.csv')
Y_train=pd.read_csv('y_train_encoded.csv')
X_test=pd.read_csv('x_test_encoded.csv')
Y_test=pd.read_csv('y_test_encoded.csv')

# %%
X_train.sample(5)
# Out:
#      Pclass  SibSp  Parch     Fare   Age  Sex_male  Embarked_Q  Embarked_S
# 561       3      0      0   8.6625  38.0         1           0           1
# 516       3      8      2  65.6344  39.0         1           0           1
# 603       1      1      0  65.6344  60.0         0           0           0
# 141       1      0      0  35.0000  56.0         1           0           1
# 303       2      0      0  13.0000  34.0         0           0           1

# %%
sns.distplot(X_train['Fare'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\1281908091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
X_train.dtypes
# Out:
# Pclass          int64
# SibSp           int64
# Parch           int64
# Fare          float64
# Age           float64
# Sex_male        int64
# Embarked_Q      int64
# Embarked_S      int64
# dtype: object

# %%
sns.distplot(X_train['Pclass'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\3010620020.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Pclass'])
# <Axes: xlabel='Pclass', ylabel='Density'>

# %%
sns.distplot(X_train['SibSp'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\651064356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['SibSp'])
# <Axes: xlabel='SibSp', ylabel='Density'>

# %%
sns.distplot(X_train['Parch'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\3696583457.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Parch'])
# <Axes: xlabel='Parch', ylabel='Density'>

# %%
sns.distplot(X_train['Fare'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\1281908091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.distplot(X_train['Age'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\468893779.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(X_train['Sex_male'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\1728192135.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Sex_male'])
# <Axes: xlabel='Sex_male', ylabel='Density'>

# %%
sns.distplot(X_train['Embarked_Q'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\2784999550.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Embarked_Q'])
# <Axes: xlabel='Embarked_Q', ylabel='Density'>

# %%
sns.distplot(X_train['Embarked_S'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_4564\1692860284.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Embarked_S'])
# <Axes: xlabel='Embarked_S', ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
ss=StandardScaler()
mms=MinMaxScaler()

# %%
X_train.columns
# Out:
# Index(['Pclass', 'SibSp', 'Parch', 'Fare', 'Age', 'Sex_male', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
norm_dist_col=['Age']
skewed_col=['Pclass', 'SibSp', 'Parch', 'Fare', 'Sex_male', 'Embarked_Q',
       'Embarked_S']

# %%
X_train[norm_dist_col]=ss.fit_transform(X_train[norm_dist_col])
X_test[norm_dist_col]=ss.transform(X_test[norm_dist_col])

# %%
X_train[skewed_col]=ss.fit_transform(X_train[skewed_col])
X_test[skewed_col]=ss.transform(X_test[skewed_col])

# %%
X_train
# Out:
#        Pclass     SibSp     Parch      Fare       Age  Sex_male  Embarked_Q  \
# 0   -1.583108 -0.493196 -0.500208  0.193742  1.097770  0.747124   -0.311432
# 1   -0.381119 -0.493196 -0.500208 -0.557240 -0.425408  0.747124   -0.311432
# 2    0.820871 -0.493196 -0.500208 -0.803126  0.183863  0.747124   -0.311432
# 3    0.820871  0.355981 -0.500208 -0.806556 -0.222318  0.747124   -0.311432
# 4    0.820871  2.903514  1.957743  0.328192 -1.576254 -1.338465   -0.311432
# ..        ...       ...       ...       ...       ...       ...         ...
# 651  0.820871 -0.493196 -0.500208 -0.816450 -0.560802 -1.338465   -0.311432
# 652 -1.583108 -0.493196 -0.500208  0.314868  0.048470  0.747124   -0.311432
# 653  0.820871  1.205159 -0.500208 -0.503542  0.793134  0.747124   -0.311432
# 654 -1.583108  0.355981  1.957743  1.992920 -1.034679 -1.338465   -0.311432
# 655 -1.583108 -0.493196  0.728767  1.992920 -0.560802  0.747124   -0.311432
#
#      Embarked_S
# 0      0.610234
# 1      0.610234
# ...

# %%
X_train.to_csv('X_train_scale',index=False)
X_test.to_csv('X_test_scale',index=False)
Y_train.to_csv('X_train_scale',index=False)
X_test.to_csv('X_train_scale',index=False)
