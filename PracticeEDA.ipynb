# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample
# Out:
# <bound method NDFrame.sample of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.sample(4)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 303          304         1       2                      Keane, Miss. Nora A
# 291          292         1       1  Bishop, Mrs. Dickinson H (Helen Walton)
# 298          299         1       1                    Saalfeld, Mr. Adolphe
# 135          136         0       2                       Richard, Mr. Emile
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 303  female   NaN      0      0         226593  12.3500  E101        Q
# 291  female  19.0      1      0          11967  91.0792   B49        C
# 298    male   NaN      0      0          19988  30.5000  C106        S
# 135    male  23.0      0      0  SC/PARIS 2133  15.0458   NaN        C

# %%
import seaborn as sns

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.countplot(df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
sns.piechart(df['Sex'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.piechart(df['Sex'])
#
# AttributeError: module 'seaborn' has no attribute 'piechart'

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.3f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Name'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.3f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df['Pclass'],bins=4)
# Out:
# <Axes: xlabel='Pclass', ylabel='Count'>

# %%
sns.displot(df['Age'],bins=6)

# %%
sns.histplot(['Age'],bins=3)
# Out:
# <Axes: ylabel='Count'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.boxplot(['Fare'])
# Out:
# <Axes: >

# %%
sns.boxplot(['Cabin'])
# Out:
# <Axes: >

# %%
sns.distplot(['Cabin'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_9564\2312665107.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(['Cabin'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sns.distplot(['Cabin'])
#
# File ~\AppData\Local\anaconda3\envs\ML\lib\site-packages\seaborn\distributions.py:2443, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2440     a = x
#    2442 # Make a a 1-d float array
# ...

# %%
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 530          531         1       2        Quick, Miss. Phyllis May  female
# 134          135         0       2  Sobey, Mr. Samuel James Hayden    male
#
#       Age  SibSp  Parch      Ticket  Fare Cabin Embarked
# 530   2.0      1      1       26360  26.0   NaN        S
# 134  25.0      0      0  C.A. 29178  13.0   NaN        S

# %%
sns.distplot(df['Fare'])
# Out:
# C:\Users\Kinza\AppData\Local\Temp\ipykernel_9564\3425841524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.scatterplot(data=df,x='Age',y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.pairplot(df)

# %%
#sns.lineplot(data=df,x='survived',y='Fare')
sns.lineplot(data=df,x='Survived',y='Fare')
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sns.barplot(data=df,x='Sex',y='Age')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(data=df,x='Sex',y='Age')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.heatmap(pd.crosstab(df['Sex'],df['Ca']))
# Out:
# <Axes: xlabel='Name', ylabel='Sex'>
