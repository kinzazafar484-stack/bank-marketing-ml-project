# %%
import pandas as pd
data=[10,29,45,34]
df=pd.DataFrame(data,columns=['Marks'])
print(df)
# Out:
#    Marks
# 0     10
# 1     29
# 2     45
# 3     34

# %%
import pandas as pd
data=[['Ali',34],['Sara',45],['Hussan',53]]
df=pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0     Ali   34
# 1    Sara   45
# 2  Hussan   53

# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data=[[1,'Kinza',21,'BSCS','6th'],[2,'Alisha',20,'BSCS','4th'],[3,'Amina',19,'BSCS','2nd'],[4,'Sara',23,'BSCS','8th']]
df=pd.DataFrame(data,columns=['Id','Name','Age','Class','Semester'])
print(df)
# Out:
#    Id    Name  Age Class Semester
# 0   1   Kinza   21  BSCS      6th
# 1   2  Alisha   20  BSCS      4th
# 2   3   Amina   19  BSCS      2nd
# 3   4    Sara   23  BSCS      8th

# %%
data={'Name':['Huma','Ali','Ahmed','Hamid','Shiz','Sheen'],'Age':[24,56,74,32,21,23]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0   Huma   24
# 1    Ali   56
# 2  Ahmed   74
# 3  Hamid   32
# 4   Shiz   21
# 5  Sheen   23
