# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.1-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 837.5 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/11.3 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/11.3 MB 1.1 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.3/11.3 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.3 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/11.3 MB 1.0 MB/s eta 0:00:10
# ...

# %%
import pandas as pd

# %%
data=[1,2,3]
df=pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
data={'name':['ali','sara'],'age':[10,20]}
df=pd.DataFrame(data)
print(df)
# Out:
#    name  age
# 0   ali   10
# 1  sara   20

# %%
data=[['ali',10],['sara',20]]
df=pd.DataFrame(data,colums=['Name','Age'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 data=[['ali',10],['sara',20]]
# ----> 2 df=pd.DataFrame(data,index,colums=['Name','Age'])
#       3 print(df)
#
# NameError: name 'index' is not defined

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.9 MB 2.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/8.9 MB 2.0 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.9 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/8.9 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.6/8.9 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/8.9 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.1/8.9 MB 1.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.7/8.9 MB 1.9 MB/s eta 0:00:03
#    ------------------ --------------------- 4.2/8.9 MB 1.9 MB/s eta 0:00:03
#    -------------------- ------------------- 4.5/8.9 MB 1.9 MB/s eta 0:00:03
# ...
